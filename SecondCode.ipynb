# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/Thubelihle Dube/Downloads/top100banks2017-12-31.csv')
print(df)

print("SUMMARY OF DATA:")
df.info()
print("MISSING VALUES:")
missing_values=df.isnull().sum
print(missing_values)
print(df.dtypes)
# Out:
#      index  rank                                   bank      country  \
# 0        0     1  Industrial & Commercial Bank of China        China
# 1        1     2           China Construction Bank Corp        China
# 2        2     3             Agricultural Bank of China        China
# 3        3     4                          Bank of China        China
# 4        4     5         Mitsubishi UFJ Financial Group        Japan
# ..     ...   ...                                    ...          ...
# 115    115   116                    Qatar National Bank        Qatar
# 116    116   117                National Bank of Canada       Canada
# 117    117   118                         Suntrust Banks          USA
# 118    118   119                 Korea Development Bank  South Korea
# 119    119   120                                Belfius      Belgium
#
#      total_assets_us_b balance_sheet
# 0             4005.580    2017-12-31
# 1             3397.130    2017-12-31
# 2             3232.680    2017-12-31
# 3             2989.160    2017-12-31
# 4             2773.820    2017-12-31
# ..                 ...           ...
# 115            221.180    2017-12-31
# 116            208.408    2017-12-31
# 117            205.962    2017-12-31
# 118            205.145    2016-12-31
# 119            201.192    2017-12-31
#
# [120 rows x 6 columns]
# SUMMARY OF DATA:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              120 non-null    int64
#  1   rank               120 non-null    int64
#  2   bank               120 non-null    object
#  3   country            120 non-null    object
#  4   total_assets_us_b  120 non-null    float64
#  5   balance_sheet      120 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 5.8+ KB
# MISSING VALUES:
# <bound method DataFrame.sum of      index   rank   bank  country  total_assets_us_b  balance_sheet
# 0    False  False  False    False              False          False
# 1    False  False  False    False              False          False
# 2    False  False  False    False              False          False
# 3    False  False  False    False              False          False
# 4    False  False  False    False              False          False
# ..     ...    ...    ...      ...                ...            ...
# 115  False  False  False    False              False          False
# 116  False  False  False    False              False          False
# 117  False  False  False    False              False          False
# 118  False  False  False    False              False          False
# 119  False  False  False    False              False          False
#
# [120 rows x 6 columns]>
# index                  int64
# rank                   int64
# bank                  object
# country               object
# total_assets_us_b    float64
# balance_sheet         object
# dtype: object

# %%
df.dropna(inplace = True)
print(df)
# Out:
#      index  rank                                   bank      country  \
# 0        0     1  Industrial & Commercial Bank of China        China
# 1        1     2           China Construction Bank Corp        China
# 2        2     3             Agricultural Bank of China        China
# 3        3     4                          Bank of China        China
# 4        4     5         Mitsubishi UFJ Financial Group        Japan
# ..     ...   ...                                    ...          ...
# 115    115   116                    Qatar National Bank        Qatar
# 116    116   117                National Bank of Canada       Canada
# 117    117   118                         Suntrust Banks          USA
# 118    118   119                 Korea Development Bank  South Korea
# 119    119   120                                Belfius      Belgium
#
#      total_assets_us_b balance_sheet
# 0             4005.580    2017-12-31
# 1             3397.130    2017-12-31
# 2             3232.680    2017-12-31
# 3             2989.160    2017-12-31
# 4             2773.820    2017-12-31
# ..                 ...           ...
# 115            221.180    2017-12-31
# 116            208.408    2017-12-31
# 117            205.962    2017-12-31
# 118            205.145    2016-12-31
# 119            201.192    2017-12-31
#
# [120 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['index', 'rank', 'bank', 'country', 'total_assets_us_b',
#        'balance_sheet'],
#       dtype='object')

# %%
df
# Out:
#      index  rank                                   bank      country  \
# 0        0     1  Industrial & Commercial Bank of China        China
# 1        1     2           China Construction Bank Corp        China
# 2        2     3             Agricultural Bank of China        China
# 3        3     4                          Bank of China        China
# 4        4     5         Mitsubishi UFJ Financial Group        Japan
# ..     ...   ...                                    ...          ...
# 115    115   116                    Qatar National Bank        Qatar
# 116    116   117                National Bank of Canada       Canada
# 117    117   118                         Suntrust Banks          USA
# 118    118   119                 Korea Development Bank  South Korea
# 119    119   120                                Belfius      Belgium
#
#      total_assets_us_b balance_sheet
# 0             4005.580    2017-12-31
# 1             3397.130    2017-12-31
# 2             3232.680    2017-12-31
# 3             2989.160    2017-12-31
# 4             2773.820    2017-12-31
# ..                 ...           ...
# 115            221.180    2017-12-31
# 116            208.408    2017-12-31
# 117            205.962    2017-12-31
# 118            205.145    2016-12-31
# 119            201.192    2017-12-31
#
# [120 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['index', 'rank', 'bank', 'country', 'total_assets_us_b',
#        'balance_sheet'],
#       dtype='object')

# %%
df
# Out:
#      index  rank                                   bank      country  \
# 0        0     1  Industrial & Commercial Bank of China        China
# 1        1     2           China Construction Bank Corp        China
# 2        2     3             Agricultural Bank of China        China
# 3        3     4                          Bank of China        China
# 4        4     5         Mitsubishi UFJ Financial Group        Japan
# ..     ...   ...                                    ...          ...
# 115    115   116                    Qatar National Bank        Qatar
# 116    116   117                National Bank of Canada       Canada
# 117    117   118                         Suntrust Banks          USA
# 118    118   119                 Korea Development Bank  South Korea
# 119    119   120                                Belfius      Belgium
#
#      total_assets_us_b balance_sheet
# 0             4005.580    2017-12-31
# 1             3397.130    2017-12-31
# 2             3232.680    2017-12-31
# 3             2989.160    2017-12-31
# 4             2773.820    2017-12-31
# ..                 ...           ...
# 115            221.180    2017-12-31
# 116            208.408    2017-12-31
# 117            205.962    2017-12-31
# 118            205.145    2016-12-31
# 119            201.192    2017-12-31
#
# [120 rows x 6 columns]

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

df_limited = df.head(8)
features = ['rank', 'total_assets_us_b']

X = df_limited[features]
y = df_limited['index']

dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)

plt.figure(figsize=(12, 8))
tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.2, 0.9375, 'total_assets_us_b <= 2434.94\ngini = 0.875\nsamples = 8\nvalue = [1, 1, 1, 1, 1, 1, 1, 1]'),
#  Text(0.1, 0.8125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 0, 1]'),
#  Text(0.3, 0.8125, 'total_assets_us_b <= 2527.685\ngini = 0.857\nsamples = 7\nvalue = [1, 1, 1, 1, 1, 1, 1, 0]'),
#  Text(0.2, 0.6875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1, 0]'),
#  Text(0.4, 0.6875, 'rank <= 1.5\ngini = 0.833\nsamples = 6\nvalue = [1, 1, 1, 1, 1, 1, 0, 0]'),
#  Text(0.3, 0.5625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0, 0]'),
#  Text(0.5, 0.5625, 'rank <= 2.5\ngini = 0.8\nsamples = 5\nvalue = [0, 1, 1, 1, 1, 1, 0, 0]'),
#  Text(0.4, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0, 0]'),
#  Text(0.6, 0.4375, 'total_assets_us_b <= 2653.71\ngini = 0.75\nsamples = 4\nvalue = [0, 0, 1, 1, 1, 1, 0, 0]'),
#  Text(0.5, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0, 0]'),
#  Text(0.7, 0.3125, 'rank <= 3.5\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 1, 0, 0, 0]'),
#  Text(0.6, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0, 0]'),
#  Text(0.8, 0.1875, 'total_assets_us_b <= 2881.49\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0, 0, 0]'),
#  Text(0.7, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0, 0]'),
#  Text(0.9, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0, 0]')]

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.plot(df.index, df['total_assets_us_b'])
plt.title('ARIMA')
plt.xlabel('Indexes')
plt.ylabel('Total assets')
plt.show()
